# %% [markdown]
# Data Pre-Processing
# Dataset : IRIS DATASET

# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd

# %%
iris_data=pd.read_csv("C:/Users/DELL/Downloads/iris-data.csv")
iris_data.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
iris_data=pd.read_csv("C:/Users/DELL/Downloads/iris-data.csv")
iris_data.head(151)
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# 5                5.4             3.9              1.7             0.4
# 6                4.6             3.4              1.4             0.3
# 7                5.0             3.4              1.5             NaN
# 8                4.4             2.9              1.4             NaN
# 9                4.9             3.1              1.5             NaN
# 10               5.4             3.7              1.5             NaN
# 11               4.8             3.4              1.6             NaN
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import seaborn as sb

# %%
sb.pairplot(iris_data.dropna(),hue='class')

# %%
iris_data.loc[(iris_data['sepal_length_cm'].isnull())|(iris_data['sepal_width_cm'].isnull())|(iris_data['petal_length_cm'].isnull())|(iris_data['petal_width_cm'].isnull())]
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
#
#           class
# 7   Iris-setosa
# 8   Iris-setosa
# 9   Iris-setosa
# 10  Iris-setosa
# 11  Iris-setosa

# %%
iris_data.loc[iris_data['class']=='Iris-setosa','sepal_width_cm'].hist()

# %%
iris_data=iris_data.loc[(iris_data['class']!='Iris-setosa')]
print(iris_data)
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 18             5.700             3.8              1.7             0.3
# 50             7.000             3.2              4.7             1.4
# 51             6.400             3.2              4.5             1.5
# 52             6.900             3.1              4.9             1.5
# 53             5.500             2.3              4.0             1.3
# 54             6.500             2.8              4.6             1.5
# 55             5.700             2.8              4.5             1.3
# 56             6.300             3.3              4.7             1.6
# 57             4.900             2.4              3.3             1.0
# 58             6.600             2.9              4.6             1.3
# 59             5.200             2.7              3.9             1.4
# 60             5.000             2.0              3.5             1.0
# ...

# %%
average_petal_width=iris_data.loc[(iris_data['class']=='Iris-setosa','petal_width_cm')].mean()
print(average_petal_width)
# Out:
# nan

# %%
averages_petal_width=iris_data.loc[(iris_data['class']=='Iris-setosa')&(iris_data['petal_width_cm'].isnull()),'petal_width_cm']
print(average_petal_width)
# Out:
# Series([], Name: petal_width_cm, dtype: float64)

# %%
a=iris_data.loc[(iris_data['class']=='Iris-setosa')|(iris_data['petal_length_cm']>1.0)]
a.head(20)
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 18              5.7             3.8              1.7             0.3
# 50              7.0             3.2              4.7             1.4
# 51              6.4             3.2              4.5             1.5
# 52              6.9             3.1              4.9             1.5
# 53              5.5             2.3              4.0             1.3
# 54              6.5             2.8              4.6             1.5
# 55              5.7             2.8              4.5             1.3
# 56              6.3             3.3              4.7             1.6
# 57              4.9             2.4              3.3             1.0
# 58              6.6             2.9              4.6             1.3
# 59              5.2             2.7              3.9             1.4
# 60              5.0             2.0              3.5             1.0
# 61              5.9             3.0              4.2             1.5
# ...

# %% [markdown]
# DATASET : EMPLOYEE DATASET

# %%
import pandas as pd

# %%
employee_data=pd.read_csv("C:/Users/DELL/Downloads/emp_data.csv")
employee_data.head()
# Out:
#    id gender        bdate  educ  jobcat   salary salbegin  jobtime  prevexp  \
# 0   1      m   3-Feb-1952    15       3  $57,000  $27,000       98      144
# 1   2      m  23-May-1958    16       1  $40,200  $18,750       98       36
# 2   3      f  26-Jul-1929    12       1  $21,450  $12,000       98      381
# 3   4      f  15-Apr-1947     8       1  $21,900  $13,200       98      190
# 4   5      m   9-Feb-1955    15       1  $45,000  $21,000       98      138
#
#    minority
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
employee_data=pd.read_csv("C:/Users/DELL/Downloads/emp_data.csv")
employee_data.head(100)
# Out:
#      id gender        bdate  educ  jobcat    salary salbegin  jobtime  \
# 0     1      m   3-Feb-1952    15       3   $57,000  $27,000       98
# 1     2      m  23-May-1958    16       1   $40,200  $18,750       98
# 2     3      f  26-Jul-1929    12       1   $21,450  $12,000       98
# 3     4      f  15-Apr-1947     8       1   $21,900  $13,200       98
# 4     5      m   9-Feb-1955    15       1   $45,000  $21,000       98
# 5     6      m  22-Aug-1958    15       1   $32,100  $13,500       98
# 6     7      m  26-Apr-1956    15       1   $36,000  $18,750       98
# 7     8      f   6-May-1966    12       1   $21,900   $9,750       98
# 8     9      f  23-Jan-1946    15       1   $27,900  $12,750       98
# 9    10      f  13-Feb-1946    12       1   $24,000  $13,500       98
# 10   11      f   7-Feb-1950    16       1   $30,300  $16,500       98
# 11   12      m  11-Jan-1966     8       1   $28,350  $12,000       98
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import seaborn as sb

# %%
sb.pairplot(employee_data.dropna(),hue='jobcat')

# %%
employee_data.loc[(employee_data['id'].isnull())|(employee_data['gender'].isnull())|(employee_data['bdate'].isnull())|(employee_data['educ'].isnull())]
# Out:
# Empty DataFrame
# Columns: [id, gender, bdate, educ, jobcat, salary, salbegin, jobtime, prevexp, minority]
# Index: []

# %%
employee_data.loc[employee_data['gender']=='f','jobtime'].hist()

# %%
employee_data=employee_data.loc[(employee_data['gender']!='f')]
print(employee_data)
# Out:
#       id gender        bdate  educ  jobcat    salary salbegin  jobtime  \
# 0      1      m   3-Feb-1952    15       3   $57,000  $27,000       98
# 1      2      m  23-May-1958    16       1   $40,200  $18,750       98
# 4      5      m   9-Feb-1955    15       1   $45,000  $21,000       98
# 5      6      m  22-Aug-1958    15       1   $32,100  $13,500       98
# 6      7      m  26-Apr-1956    15       1   $36,000  $18,750       98
# 11    12      m  11-Jan-1966     8       1   $28,350  $12,000       98
# 12    13      m  17-Jul-1960    15       1   $27,750  $14,250       98
# 14    15      m  29-Aug-1962    12       1   $27,300  $13,500       97
# 15    16      m  17-Nov-1964    12       1   $40,800  $15,000       97
# 16    17      m  18-Jul-1962    15       1   $46,000  $14,250       97
# 17    18      m  20-Mar-1956    16       3  $103,750  $27,510       97
# 18    19      m  19-Aug-1962    12       1   $42,300  $14,250       97
# ...

# %%
average_jobtime=employee_data.loc[(employee_data['gender']=='m','jobtime')].mean()
print(average_jobtime)
# Out:
# 81.72093023255815

# %%
avg_jobtime=employee_data.loc[(employee_data['id']<=40)]
print(avg_jobtime)
# Out:
#     id gender        bdate  educ  jobcat    salary salbegin  jobtime  prevexp  \
# 0    1      m   3-Feb-1952    15       3   $57,000  $27,000       98      144
# 1    2      m  23-May-1958    16       1   $40,200  $18,750       98       36
# 4    5      m   9-Feb-1955    15       1   $45,000  $21,000       98      138
# 5    6      m  22-Aug-1958    15       1   $32,100  $13,500       98       67
# 6    7      m  26-Apr-1956    15       1   $36,000  $18,750       98      114
# 11  12      m  11-Jan-1966     8       1   $28,350  $12,000       98       26
# 12  13      m  17-Jul-1960    15       1   $27,750  $14,250       98       34
# 14  15      m  29-Aug-1962    12       1   $27,300  $13,500       97       66
# 15  16      m  17-Nov-1964    12       1   $40,800  $15,000       97       24
# 16  17      m  18-Jul-1962    15       1   $46,000  $14,250       97       48
# 17  18      m  20-Mar-1956    16       3  $103,750  $27,510       97       70
# ...

# %%
a=employee_data.loc[(employee_data['jobtime']==98)&(employee_data['minority']==1)]
a.head(15)
# Out:
#     id gender        bdate  educ  jobcat   salary salbegin  jobtime  prevexp  \
# 11  12      m  11-Jan-1966     8       1  $28,350  $12,000       98       26
# 12  13      m  17-Jul-1960    15       1  $27,750  $14,250       98       34
#
#     minority
# 11         1
# 12         1
